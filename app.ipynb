# %%
import pandas as pd

# Load the CSV file into a DataFrame
data = pd.read_csv("all_job_offers.csv")

data
# Out:
# /tmp/ipykernel_1846/3043656198.py:4: DtypeWarning: Columns (17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("all_job_offers.csv")
#                                                 job_title        city  \
# 0            Chargés de Clientèle en Assistance Technique  Casablanca
# 1                                             1  42 PHP 3      zerzer
# 2                                                    JAVA  PARIS (75)
# 3                                        110   Negotiator      Berlin
# 4                   Responsable logistique et prodruction   Mohamédia
# ...                                                   ...         ...
# 123986  Référant fonctionnel et d'intégration de SI ba...  Rabat/Casa
# 123987                                      Chef d'Agence  Casablanca
# 123988                  Chargé de la Gestion du Transport  Casablanca
# 123989                  Responsable Commercial Menuisiers  Casablanca
# ...

# %%
data.columns
# Out:
# Index(['job_title', 'city', 'function', 'sector', 'Expérience requise',
#        'Région', 'Niveau d'étude et formation', 'Type de contrat',
#        'Télétravail', 'soft_skills', 'Entreprise', 'Poste', 'Profil recherché',
#        'Adresse', 'recruiter_id', 'job_offer_id', 'Poste avec Management',
#        'Qualités requises pour réussir dans ce rôle',
#        'Ce que vous pouvez attendre de nous', 'pub_date', 'exp_date',
#        'pub_date_day', 'pub_date_month', 'pub_date_year', 'exp_date_day',
#        'exp_date_month', 'exp_date_year'],
#       dtype='object')

# %%
import pandas as pd
    
# Sélectionner les colonnes pertinentes
columns_to_keep = ['job_title', 'function', 'sector', 'Expérience requise', 
        "Niveau d'étude et formation", 'Type de contrat', 'Télétravail', 
        'soft_skills', 'Profil recherché', 'Qualités requises pour réussir dans ce rôle']
    

data=data[columns_to_keep]

# %%
data
# Out:
#                                                 job_title  \
# 0            Chargés de Clientèle en Assistance Technique
# 1                                             1  42 PHP 3
# 2                                                    JAVA
# 3                                        110   Negotiator
# 4                   Responsable logistique et prodruction
# ...                                                   ...
# 123986  Référant fonctionnel et d'intégration de SI ba...
# 123987                                      Chef d'Agence
# 123988                  Chargé de la Gestion du Transport
# 123989                  Responsable Commercial Menuisiers
# 123990  Service Desk Operators Franco anglophone (N1 N...
#
#                                              function  \
# 0                           Call Centers (métiers de)
# 1                            Journalisme / Traduction
# 2                      Communication / Publicité / RP
# ...
